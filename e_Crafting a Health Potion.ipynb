# %% [markdown]
# # Crafting a Health Potion Project

# %% [markdown]
# What is covered in this notebook:
# - 1 - Creating a Script in Python IDLE
#     - a) create a variable called health
#     - b) import the random module in Python IDLE
#     - c) researching/understanding "randint(a,) function
#     - d) creating a variable that stores a random number between 25 and 50
# - 2 - Creat a new health value by adding the random health variable to the current player's health value
#     - a) Create a new value for the variable health, by taking the current health variable and adding the potion_health
# - 3 - Create the difficulty variables & modify health potion considering the health potion
#     - a) divide the potion health by difficulty
#     - b) "Casting" the potion_health variable into another data type

# %% [markdown]
# ![image.png](attachment:image.png)
