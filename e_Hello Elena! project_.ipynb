# %% [markdown]
# # Hello You!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Outline

# %% [markdown]
# - 1 - Ask user for name.
# - 2 - Ask user for age.
# - 3 - Ask user where they live.
# - 4 - Ask user what they enjoy!
# - 5 - Create output text.
# - 6 - Print output to the screen.
#
# ** this was also created as a .py script

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Ask user for their name

name = input ("What is your name?: ")
print(name)
# Out:
# What is your name?: Elena
# Elena

# %%
#Ask user for age

age = input ("What is your age?: ")
print(age)
# Out:
# What is your age?: ummm.. why do you ask?
# ummm.. why do you ask?

# %%
#Ask user where they live.
city = input ("What city do you live in?: ")
# Out:
# What city do you live in?: Wouldn't you like to know?

# %%
#Ask user what they enjoy!
love = input ("What do you love doing?: ")
# Out:
# What do you love doing?: Working with data.

# %%
#Create output text
string= "Your name is {} and you are {} years old.  You live in {} and you love {}."
output = string.format(name, age, city, love)

# %%
#print output of string
print(output)
# Out:
# Your name is Elena and you are ummm.. why do you ask? years old.  You live in Wouldn't you like to know? and you love Working with data..
